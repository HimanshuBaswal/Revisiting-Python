# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
nax = np.arange(1,9)

# %%
nay = np.arange(3,27,3)

# %%
nax
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
nay
# Out:
# array([ 3,  6,  9, 12, 15, 18, 21, 24])

# %%
plt.plot(nax, nay, color = 'orange')
plt.show()

# %%
plt.xlabel("NAX")
plt.ylabel("NAY")
plt.title("Plot")
plt.plot(nax, nay)
plt.show()

# %%
lsx = np.linspace(-4,4,50)
lsy = lsx**2

# %%
plt.plot(lsx,lsy, "y.")
plt.show()

# %%
plt.plot(lsx, np.sin(lsx),"r.")
plt.plot(lsx, np.cos(lsx),"g--")
plt.show()

# %%
plt.bar(nax,nay)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.barh(nax,nay)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.polar(nax,nay)

# %%
plt.step(nax,nay)

# %%
from pylab import *

# %%
x = linspace(-3,3,30)

# %%
y = x ** 2

# %%
plot(x,y)

# %%
figure = plt.figure()

# %%
X = np.arange(-1,5,0.1)

# %%
X
# Out:
# array([-1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
#        -2.00000000e-01, -1.00000000e-01, -2.22044605e-16,  1.00000000e-01,
#         2.00000000e-01,  3.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         6.00000000e-01,  7.00000000e-01,  8.00000000e-01,  9.00000000e-01,
#         1.00000000e+00,  1.10000000e+00,  1.20000000e+00,  1.30000000e+00,
#         1.40000000e+00,  1.50000000e+00,  1.60000000e+00,  1.70000000e+00,
#         1.80000000e+00,  1.90000000e+00,  2.00000000e+00,  2.10000000e+00,
#         2.20000000e+00,  2.30000000e+00,  2.40000000e+00,  2.50000000e+00,
#         2.60000000e+00,  2.70000000e+00,  2.80000000e+00,  2.90000000e+00,
#         3.00000000e+00,  3.10000000e+00,  3.20000000e+00,  3.30000000e+00,
#         3.40000000e+00,  3.50000000e+00,  3.60000000e+00,  3.70000000e+00,
# ...

# %%
Y = np.exp(-X)*np.cos(5*X)

# %%
y
# Out:
# array([9.        , 7.80142687, 6.68846611, 5.66111772, 4.71938169,
#        3.86325803, 3.09274673, 2.4078478 , 1.80856124, 1.29488704,
#        0.86682521, 0.52437574, 0.26753864, 0.09631391, 0.01070155,
#        0.01070155, 0.09631391, 0.26753864, 0.52437574, 0.86682521,
#        1.29488704, 1.80856124, 2.4078478 , 3.09274673, 3.86325803,
#        4.71938169, 5.66111772, 6.68846611, 7.80142687, 9.        ])

# %%
plt.plot(X,Y)

# %%
plt.figure(figsize = (10,8))
plt.plot(X,Y)

# %%
plt.figure(dpi = (100))
plt.stackplot(X,Y)

# %%
plt.figure(facecolor = 'red')
plt.plot(X,Y)

# %%
X1 = np.arange(1,9)

# %%
X1
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
Y1 = np.arange(3,27,3)
Y1
# Out:
# array([ 3,  6,  9, 12, 15, 18, 21, 24])

# %%
plt.plot(X1,Y1)

# %%
plt.subplot(2,2,1)
plt.plot(X1,Y1,"red")
plt.subplot(2,2,2)
plt.plot(Y1,Y1,'blue')
plt.subplot(2,2,3)
plt.plot(X1,X1,'yellow')
plt.subplot(2,2,4)
plt.plot(Y1,X1,'black')

# %%
plt.subplot(2,2,1)
plt.plot(X1,X1*X1,'red')
plt.subplot(2,2,2)
plt.plot(X1,np.sqrt(X1),'blue')
plt.subplot(2,2,3)
plt.plot(X1,np.exp(X1),'black')
plt.subplot(2,2,4)
plt.plot(X1,np.log10(X1),'yellow')

# %%
fig = plt.figure()

# %%
axes = fig.add_axes([0,0,1,1])

# %%
fig

# %%
axes.plot(X1,Y1,"red")

# %%
fig

# %%
axes.set_xlabel("X1 Values")
axes.set_ylabel("Y1 Values")
# Out:
# Text(3.1999999999999993, 0.5, 'Y1 Values')

# %%
fig

# %%
axes.set_title("X1 vs Y1 Graph")
# Out:
# Text(0.5, 1.0, 'X1 vs Y1 Graph')

# %%
fig

# %%
axes.legend(labels = 'Label',loc="lower right")
fig

# %%
axes2 = fig.add_axes([0.1,0.6,0.4,0.35])

# %%
fig

# %%
axes2.plot(X,Y,"blue")

# %%
fig

# %%
axes2.set_title("X-Y Graph")
axes2.set_xlabel("X Values")
axes2.set_ylabel("Y Values")
axes2.legend(labels="X-Y", loc = 'lower right')

# %%
fig

# %%
fig1, axes1 = plt.subplots(nrows=2,ncols=2)
plt.tight_layout()

# %%
print(type(axes1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(axes1[0])
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
print(axes1[1])
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
fig.savefig("fig.pdf")

# %%
x = np.random.randint(1,12,5)
y = np.random.randint(1,10,5)

# %%
x
# Out:
# array([3, 7, 9, 8, 2])

# %%
y
# Out:
# array([4, 9, 2, 6, 4])

# %%
fig0 = plt.figure()

axes0 = fig.add_axes([0,0,1,1])

axes0.plot(X,Y**2, color = "green")
# Out:
# <ipython-input-99-ab9a8f89d6e3>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes0 = fig.add_axes([0,0,1,1])

# %%
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
x = [1,2,3,4,5]
y = [0,2,4,6,8]

plt.figure(figsize=(5,3), dpi=100)

#plt.plot(x,y, label='2x',color='#C37B89',linewidth = 3, marker = ".", markersize=10,linestyle = '--',markeredgecolor='blue')
plt.plot(x,y, 'b^--' ,label='2x')

x2 = np.arange(0,4.5,0.5)
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
plt.plot(x2[5:], x2[5:]**2, 'r--')

plt.xlabel(" X Axis")
plt.ylabel(" Y Axis")
plt.title("Our first graph", fontdict = {'fontname': 'Comic Sans MS', 'fontsize' : 20})

plt.xticks([0,1,2,3,4,])
plt.yticks([0,2,4,6,8,10])

plt.legend()
plt.show()

# %%
labels = ["A" ,"B","C"]
values = [1,4,2]

bars = plt.bar(labels,values)

patterns = ['/','O','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
    
plt.figure(figsize = (6,4))

plt.show()
