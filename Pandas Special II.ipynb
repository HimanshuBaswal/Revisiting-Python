# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series

# %%
p_series = pd.Series([7,11,19,113])

# %%
p_series
# Out:
# 0      7
# 1     11
# 2     19
# 3    113
# dtype: int64

# %%
p_series2 = pd.Series([29,range(5)])

# %%
p_series2
# Out:
# 0                 29
# 1    (0, 1, 2, 3, 4)
# dtype: object

# %%
p_series[3]
# Out:
# 113

# %%
p_series_3 = pd.Series(np.random.randint(1,150,20))

# %%
p_series_3
# Out:
# 0      36
# 1      37
# 2      31
# 3      73
# 4     140
# 5     112
# 6      70
# 7     120
# 8      82
# 9      62
# 10     86
# 11     39
# 12      5
# 13     88
# 14      7
# 15      8
# 16    144
# 17      1
# 18     30
# 19    147
# dtype: int32

# %%
p_series_3.max()
# Out:
# 147

# %%
p_series_3.min()
# Out:
# 1

# %%
p_series_3.mean()
# Out:
# 65.9

# %%
p_series_3.std()
# Out:
# 48.2077739963609

# %%
p_series_3.describe()
# Out:
# count     20.000000
# mean      65.900000
# std       48.207774
# min        1.000000
# 25%       30.750000
# 50%       66.000000
# 75%       94.000000
# max      147.000000
# dtype: float64

# %%
p_series_3.head()
# Out:
# 0     36
# 1     37
# 2     31
# 3     73
# 4    140
# dtype: int32

# %%
p_series_3.tail()
# Out:
# 15      8
# 16    144
# 17      1
# 18     30
# 19    147
# dtype: int32

# %%
p_series_4 = pd.Series([5,13,23,29], index = ['Joe','William','Jack','Avarell'])

# %%
p_series_4
# Out:
# Joe         5
# William    13
# Jack       23
# Avarell    29
# dtype: int64

# %%
p_series_4['Avarell']
# Out:
# 29

# %%
p_series_4.Joe
# Out:
# 5

# %%
p_series_D = pd.Series({"One":1, "Two":2, "Three":3, "Four":4, "Five":5})

# %%
p_series_D
# Out:
# One      1
# Two      2
# Three    3
# Four     4
# Five     5
# dtype: int64

# %%
p_series_S = pd.Series(["Tom","Jerry","Spike","Tyke","Nibbles","Quacker"])

# %%
p_series_S
# Out:
# 0        Tom
# 1      Jerry
# 2      Spike
# 3       Tyke
# 4    Nibbles
# 5    Quacker
# dtype: object

# %%
p_series_S.str.contains("e")
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
p_series_S.str.upper()
# Out:
# 0        TOM
# 1      JERRY
# 2      SPIKE
# 3       TYKE
# 4    NIBBLES
# 5    QUACKER
# dtype: object

# %%
Data = [1,2,3,4,5,6]

# %%
Label = ["apple","cherry","banana","orange","pear","melon"]

# %%
pd.Series(data=Data, index=Label)
# Out:
# apple     1
# cherry    2
# banana    3
# orange    4
# pear      5
# melon     6
# dtype: int64

# %%
SD_LW = pd.Series([70,63,150,45,33,35],["Chocolate","Bread","Biscuits","Potatoes(kg)","Carrots(kg)","Chips"])

# %%
SD_TW = pd.Series([45,51,90,67,44,13],["Chocolate","Bread","Biscuits","Potatoes(kg)","Carrots(kg)","Crackers"])

# %%
SD_LW
# Out:
# Chocolate        70
# Bread            63
# Biscuits        150
# Potatoes(kg)     45
# Carrots(kg)      33
# Chips            35
# dtype: int64

# %%
SD_TW
# Out:
# Chocolate       45
# Bread           51
# Biscuits        90
# Potatoes(kg)    67
# Carrots(kg)     44
# Crackers        13
# dtype: int64

# %%
SD_LW + SD_TW
# Out:
# Biscuits        240.0
# Bread           114.0
# Carrots(kg)      77.0
# Chips             NaN
# Chocolate       115.0
# Crackers          NaN
# Potatoes(kg)    112.0
# dtype: float64

# %% [markdown]
# ### DataFrames

# %%
P_Dict_Sales = {"Chocolate":[70,45,65],
               "Biscuits":[150,90,143],
               "Potatoes(kg)":[45,67,38],
               "Carrots(kg)":[33,44,45],
               "Chips":[35,0,28],
               "Crackers":[0,13,45]}

# %%
p_dframes = pd.DataFrame(P_Dict_Sales)

# %%
p_dframes
# Out:
#    Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# 0         70       150            45           33     35         0
# 1         45        90            67           44      0        13
# 2         65       143            38           45     28        45

# %%
p_dframes = pd.DataFrame(P_Dict_Sales, index = ["Week 1","Week 2","Week 3"])

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70       150            45           33     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
p_dframes["Biscuits"]
# Out:
# Week 1    150
# Week 2     90
# Week 3    143
# Name: Biscuits, dtype: int64

# %%
p_dframes.Crackers
# Out:
# Week 1     0
# Week 2    13
# Week 3    45
# Name: Crackers, dtype: int64

# %%
p_dframes.loc["Week 1"]
# Out:
# Chocolate        70
# Biscuits        150
# Potatoes(kg)     45
# Carrots(kg)      33
# Chips            35
# Crackers          0
# Name: Week 1, dtype: int64

# %%
p_dframes.iloc[1]
# Out:
# Chocolate       45
# Biscuits        90
# Potatoes(kg)    67
# Carrots(kg)     44
# Chips            0
# Crackers        13
# Name: Week 2, dtype: int64

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70       150            45           33     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
p_dframes[p_dframes >= 50]
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1       70.0       150           NaN          NaN    NaN       NaN
# Week 2        NaN        90          67.0          NaN    NaN       NaN
# Week 3       65.0       143           NaN          NaN    NaN       NaN

# %%
p_dframes[(p_dframes>=0)&(p_dframes<50)]
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1        NaN       NaN          45.0           33     35         0
# Week 2       45.0       NaN           NaN           44      0        13
# Week 3        NaN       NaN          38.0           45     28        45

# %%
p_dframes[(p_dframes >= 100)|(p_dframes < 50)]
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1        NaN     150.0          45.0           33     35         0
# Week 2       45.0       NaN           NaN           44      0        13
# Week 3        NaN     143.0          38.0           45     28        45

# %%
p_dframes.at['Week 1','Chocolate']
# Out:
# 70

# %%
p_dframes.iat[0,3]
# Out:
# 33

# %%
p_dframes.at["Week 1","Chocolate"] = 66

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         66       150            45           33     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
p_dframes.iat[0,3] = 75

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         66       150            45           75     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
pd.set_option("precision",2)
p_dframes.describe()
# Out:
#        Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# count       3.00      3.00          3.00         3.00   3.00      3.00
# mean       58.67    127.67         50.00        54.67  21.00     19.33
# std        11.85     32.81         15.13        17.62  18.52     23.16
# min        45.00     90.00         38.00        44.00   0.00      0.00
# 25%        55.00    116.50         41.50        44.50  14.00      6.50
# 50%        65.00    143.00         45.00        45.00  28.00     13.00
# 75%        65.50    146.50         56.00        60.00  31.50     29.00
# max        66.00    150.00         67.00        75.00  35.00     45.00

# %%
p_dframes.mean()
# Out:
# Chocolate        58.67
# Biscuits        127.67
# Potatoes(kg)     50.00
# Carrots(kg)      54.67
# Chips            21.00
# Crackers         19.33
# dtype: float64

# %%
p_dframes.T
# Out:
#               Week 1  Week 2  Week 3
# Chocolate         66      45      65
# Biscuits         150      90     143
# Potatoes(kg)      45      67      38
# Carrots(kg)       75      44      45
# Chips             35       0      28
# Crackers           0      13      45

# %%
p_dframes.describe()
# Out:
#        Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# count       3.00      3.00          3.00         3.00   3.00      3.00
# mean       58.67    127.67         50.00        54.67  21.00     19.33
# std        11.85     32.81         15.13        17.62  18.52     23.16
# min        45.00     90.00         38.00        44.00   0.00      0.00
# 25%        55.00    116.50         41.50        44.50  14.00      6.50
# 50%        65.00    143.00         45.00        45.00  28.00     13.00
# 75%        65.50    146.50         56.00        60.00  31.50     29.00
# max        66.00    150.00         67.00        75.00  35.00     45.00

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         66       150            45           75     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
p_dframes.sort_index(ascending=False)
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 3         65       143            38           45     28        45
# Week 2         45        90            67           44      0        13
# Week 1         66       150            45           75     35         0

# %%
p_dframes.sort_index(ascending=True)
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         66       150            45           75     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
p_dframes.sort_index(axis=1)
# Out:
#         Biscuits  Carrots(kg)  Chips  Chocolate  Crackers  Potatoes(kg)
# Week 1       150           75     35         66         0            45
# Week 2        90           44      0         45        13            67
# Week 3       143           45     28         65        45            38

# %%
p_dframes.sort_index(axis=0)
# Out:
#         Chocolate  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         66       150            45           75     35         0
# Week 2         45        90            67           44      0        13
# Week 3         65       143            38           45     28        45

# %%
P_Dict_Sales = {"Chocolate":[70,45,65],"Bread":[63,51,59],"Biscuits":[150,90,45],"Potatoes(kg)":[45,67,38],
                "Carrots(kg)":[33,44,55],"Chips":[35,0,28],"Crackers":[0,13,45]}

# %%
p_dframes = pd.DataFrame(P_Dict_Sales)

# %%
p_dframes = pd.DataFrame(P_Dict_Sales, index = ["Week 1","Week 2","Week 3"])

# %%
p_dframes["Onions(kg)"] = [35,49,27]

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  \
# Week 1         70     63       150            45           33     35
# Week 2         45     51        90            67           44      0
# Week 3         65     59        45            38           55     28
#
#         Crackers  Onions(kg)
# Week 1         0          35
# Week 2        13          49
# Week 3        45          27

# %%
new_row = {"Chocolate":77,
          "Bread":69,
          "Biscuits":105,
          "Potatoes(kg)":33,
          "Carrots(kg)":57,
          "Chips":44,
          "Crackers":30,
          "Onions(kg)":30}

# %%
p_dframes = p_dframes.append(new_row, ignore_index =True)

# %%
p_dframes
# Out:
#    Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers  \
# 0         70     63       150            45           33     35         0
# 1         45     51        90            67           44      0        13
# 2         65     59        45            38           55     28        45
# 3         77     69       105            33           57     44        30
#
#    Onions(kg)
# 0          35
# 1          49
# 2          27
# 3          30

# %%
new_row2 = {"Chocolate":77,
          "Bread":69,
          "Biscuits":105,
          "Potatoes(kg)":33,
          "Carrots(kg)":57,
          "Chips":44,
          "Crackers":30,
          "Onions(kg)":30}

# %%
p_dframes = p_dframes.append(new_row2, ignore_index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-1af20a8213e8> in <module>
# ----> 1 p_dframes = p_dframes.append(new_row2, ignore_index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7943             if isinstance(other, dict):
#    7944                 if not ignore_index:
# -> 7945                     raise TypeError("Can only append a dict if ignore_index=True")
#    7946                 other = Series(other)
#    7947             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
p_dframes = pd.DataFrame(P_Dict_Sales, index = ['Week 1','Week 2','Week 3'])

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59        45            38           55     28        45

# %%
n_r = pd.Series(data = {"Chocolate": 55,
                       "Bread":43,
                       "Biscuits":77,
                       "Potatoes(kg)":54,
                       "Carrots(kg)":55,
                       "Chips":23,
                       "Crackers":33,
                       "Onions(kg)":39}, name = "Week 4")

# %%
p_dframes = p_dframes.append(n_r,ignore_index=False)

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  \
# Week 1         70     63       150            45           33     35
# Week 2         45     51        90            67           44      0
# Week 3         65     59        45            38           55     28
# Week 4         55     43        77            54           55     23
#
#         Crackers  Onions(kg)
# Week 1         0         NaN
# Week 2        13         NaN
# Week 3        45         NaN
# Week 4        33        39.0

# %%
del p_dframes['Chips']

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Crackers  \
# Week 1         70     63       150            45           33         0
# Week 2         45     51        90            67           44        13
# Week 3         65     59        45            38           55        45
# Week 4         55     43        77            54           55        33
#
#         Onions(kg)
# Week 1         NaN
# Week 2         NaN
# Week 3         NaN
# Week 4        39.0

# %%
p_dframes.pop("Potatoes(kg)")
# Out:
# Week 1    45
# Week 2    67
# Week 3    38
# Week 4    54
# Name: Potatoes(kg), dtype: int64

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Carrots(kg)  Crackers  Onions(kg)
# Week 1         70     63       150           33         0         NaN
# Week 2         45     51        90           44        13         NaN
# Week 3         65     59        45           55        45         NaN
# Week 4         55     43        77           55        33        39.0

# %%
p_dframes = p_dframes.drop(["Crackers"],axis=1)

# %%
p_dframes
# Out:
#         Chocolate  Bread  Biscuits  Carrots(kg)  Onions(kg)
# Week 1         70     63       150           33         NaN
# Week 2         45     51        90           44         NaN
# Week 3         65     59        45           55         NaN
# Week 4         55     43        77           55        39.0

# %%
p_dframes = p_dframes.drop(["Bread","Carrots(kg)"], axis = 1)

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Onions(kg)
# Week 1         70       150         NaN
# Week 2         45        90         NaN
# Week 3         65        45         NaN
# Week 4         55        77        39.0

# %%
p_dframes = p_dframes.drop(["Week 4"], axis=0)

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Onions(kg)
# Week 1         70       150         NaN
# Week 2         45        90         NaN
# Week 3         65        45         NaN

# %%
P_Dict_Sale = {"Chocolate":[70,45,65,35,65,60,44],
                "Biscuits":[150,90,143,87,79,56,135],
               "Bread":[63,51,59,46,55,71,39],
               "Potatoes(kg)":[45,67,38,33,41,29,27],
               "Carrots(kg)":[33,44,45,41,46,39,51],
               "Chips":[35,0,28,70,36,43,0],
               "Crackers":[0,13,45,39,47,46,51]}

# %%
p_dframes = pd.DataFrame(P_Dict_Sale)

# %%
p_dframes = pd.DataFrame(P_Dict_Sale, index = ["Week 1","Week 2","Week 3","Week 4","Week 5","Week 6","Week 7"])

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Bread  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70       150     63            45           33     35         0
# Week 2         45        90     51            67           44      0        13
# Week 3         65       143     59            38           45     28        45
# Week 4         35        87     46            33           41     70        39
# Week 5         65        79     55            41           46     36        47
# Week 6         60        56     71            29           39     43        46
# Week 7         44       135     39            27           51      0        51

# %%
p_dframes.head()
# Out:
#         Chocolate  Biscuits  Bread  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70       150     63            45           33     35         0
# Week 2         45        90     51            67           44      0        13
# Week 3         65       143     59            38           45     28        45
# Week 4         35        87     46            33           41     70        39
# Week 5         65        79     55            41           46     36        47

# %%
p_dframes.insert(3,"Onions(kg)",[25,33,31,36,44,19,27])

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Bread  Onions(kg)  Potatoes(kg)  Carrots(kg)  \
# Week 1         70       150     63          25            45           33
# Week 2         45        90     51          33            67           44
# Week 3         65       143     59          31            38           45
# Week 4         35        87     46          36            33           41
# Week 5         65        79     55          44            41           46
# Week 6         60        56     71          19            29           39
# Week 7         44       135     39          27            27           51
#
#         Chips  Crackers
# Week 1     35         0
# Week 2      0        13
# Week 3     28        45
# Week 4     70        39
# Week 5     36        47
# Week 6     43        46
# Week 7      0        51

# %%
p_dframes["Potatoes(kg)"] = p_dframes["Potatoes(kg)"] / 10

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Bread  Onions(kg)  Potatoes(kg)  Carrots(kg)  \
# Week 1         70       150     63          25           4.5           33
# Week 2         45        90     51          33           6.7           44
# Week 3         65       143     59          31           3.8           45
# Week 4         35        87     46          36           3.3           41
# Week 5         65        79     55          44           4.1           46
# Week 6         60        56     71          19           2.9           39
# Week 7         44       135     39          27           2.7           51
#
#         Chips  Crackers
# Week 1     35         0
# Week 2      0        13
# Week 3     28        45
# Week 4     70        39
# Week 5     36        47
# Week 6     43        46
# Week 7      0        51

# %%
p_dframes["Carrots(kg)"] = p_dframes["Carrots(kg)"] + 5

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Bread  Onions(kg)  Potatoes(kg)  Carrots(kg)  \
# Week 1         70       150     63          25           4.5           38
# Week 2         45        90     51          33           6.7           49
# Week 3         65       143     59          31           3.8           50
# Week 4         35        87     46          36           3.3           46
# Week 5         65        79     55          44           4.1           51
# Week 6         60        56     71          19           2.9           44
# Week 7         44       135     39          27           2.7           56
#
#         Chips  Crackers
# Week 1     35         0
# Week 2      0        13
# Week 3     28        45
# Week 4     70        39
# Week 5     36        47
# Week 6     43        46
# Week 7      0        51

# %%
p_dframes["Onions(kg)"] +=5

# %%
p_dframes
# Out:
#         Chocolate  Biscuits  Bread  Onions(kg)  Potatoes(kg)  Carrots(kg)  \
# Week 1         70       150     63          30           4.5           38
# Week 2         45        90     51          38           6.7           49
# Week 3         65       143     59          36           3.8           50
# Week 4         35        87     46          41           3.3           46
# Week 5         65        79     55          49           4.1           51
# Week 6         60        56     71          24           2.9           44
# Week 7         44       135     39          32           2.7           56
#
#         Chips  Crackers
# Week 1     35         0
# Week 2      0        13
# Week 3     28        45
# Week 4     70        39
# Week 5     36        47
# Week 6     43        46
# Week 7      0        51

# %%
p_dframes["Chocolate"].value_counts()
# Out:
# 65    2
# 44    1
# 35    1
# 60    1
# 45    1
# 70    1
# Name: Chocolate, dtype: int64

# %% [markdown]
# ### Multi Index

# %%
outer_index = ["Group1","Group1","Group1","Group2","Group2","Group2","Group3","Group3","Group3"]

# %%
inner_index = ["Index1","Index2","Index3","Index1","Index2","Index3","Index1","Index2","Index3"]

# %%
list(zip(outer_index,inner_index))
# Out:
# [('Group1', 'Index1'),
#  ('Group1', 'Index2'),
#  ('Group1', 'Index3'),
#  ('Group2', 'Index1'),
#  ('Group2', 'Index2'),
#  ('Group2', 'Index3'),
#  ('Group3', 'Index1'),
#  ('Group3', 'Index2'),
#  ('Group3', 'Index3')]

# %%
Hierarchy = list(zip(outer_index,inner_index))

# %%
Hierarchy
# Out:
# [('Group1', 'Index1'),
#  ('Group1', 'Index2'),
#  ('Group1', 'Index3'),
#  ('Group2', 'Index1'),
#  ('Group2', 'Index2'),
#  ('Group2', 'Index3'),
#  ('Group3', 'Index1'),
#  ('Group3', 'Index2'),
#  ('Group3', 'Index3')]

# %%
Hierarchy = pd.MultiIndex.from_tuples(Hierarchy)

# %%
Hierarchy
# Out:
# MultiIndex([('Group1', 'Index1'),
#             ('Group1', 'Index2'),
#             ('Group1', 'Index3'),
#             ('Group2', 'Index1'),
#             ('Group2', 'Index2'),
#             ('Group2', 'Index3'),
#             ('Group3', 'Index1'),
#             ('Group3', 'Index2'),
#             ('Group3', 'Index3')],
#            )

# %%
Hierarchy.levels
# Out:
# FrozenList([['Group1', 'Group2', 'Group3'], ['Index1', 'Index2', 'Index3']])

# %%
Hierarchy.codes
# Out:
# FrozenList([[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
R_Value = np.random.randint(1,300,45)

# %%
R_Value = R_Value.reshape(9,5)

# %%
R_Value
# Out:
# array([[278, 297, 252,  51, 141],
#        [177, 129,  51, 172, 259],
#        [249, 207, 139, 254, 173],
#        [181, 270, 217, 148, 223],
#        [211,  15,  23, 253, 285],
#        [ 78,   8, 258,  50,  67],
#        [ 57, 168, 239, 230, 299],
#        [282, 273, 141, 261, 280],
#        [208, 112, 111, 149, 110]])

# %%
df_1 = pd.DataFrame(R_Value, Hierarchy, columns = ["Column 1","Column 2","Column 3","Column 4","Column 5"])

# %%
df_1
# Out:
#                Column 1  Column 2  Column 3  Column 4  Column 5
# Group1 Index1       278       297       252        51       141
#        Index2       177       129        51       172       259
#        Index3       249       207       139       254       173
# Group2 Index1       181       270       217       148       223
#        Index2       211        15        23       253       285
#        Index3        78         8       258        50        67
# Group3 Index1        57       168       239       230       299
#        Index2       282       273       141       261       280
#        Index3       208       112       111       149       110

# %%
df_1["Column 2"]
# Out:
# Group1  Index1    297
#         Index2    129
#         Index3    207
# Group2  Index1    270
#         Index2     15
#         Index3      8
# Group3  Index1    168
#         Index2    273
#         Index3    112
# Name: Column 2, dtype: int32

# %%
df_1.loc["Group2"]
# Out:
#         Column 1  Column 2  Column 3  Column 4  Column 5
# Index1       181       270       217       148       223
# Index2       211        15        23       253       285
# Index3        78         8       258        50        67

# %%
df_1.loc[["Group1","Group2"]]
# Out:
#                Column 1  Column 2  Column 3  Column 4  Column 5
# Group1 Index1       278       297       252        51       141
#        Index2       177       129        51       172       259
#        Index3       249       207       139       254       173
# Group2 Index1       181       270       217       148       223
#        Index2       211        15        23       253       285
#        Index3        78         8       258        50        67

# %%
df_1.loc["Group2"].loc["Index3"]
# Out:
# Column 1     78
# Column 2      8
# Column 3    258
# Column 4     50
# Column 5     67
# Name: Index3, dtype: int32

# %%
df_1.index.names = ["Groups","Indexes"]

# %%
df_1
# Out:
#                 Column 1  Column 2  Column 3  Column 4  Column 5
# Groups Indexes
# Group1 Index1        278       297       252        51       141
#        Index2        177       129        51       172       259
#        Index3        249       207       139       254       173
# Group2 Index1        181       270       217       148       223
#        Index2        211        15        23       253       285
#        Index3         78         8       258        50        67
# Group3 Index1         57       168       239       230       299
#        Index2        282       273       141       261       280
#        Index3        208       112       111       149       110

# %%
df_1.xs("Group2")
# Out:
#          Column 1  Column 2  Column 3  Column 4  Column 5
# Indexes
# Index1        181       270       217       148       223
# Index2        211        15        23       253       285
# Index3         78         8       258        50        67

# %% [markdown]
# ### Group By

# %%
covid_data = {"Country":["Japan","Malaysia","Spain","Singapore","Italy","Morocco","Germany","Egypt","USA","Canada","Brazil"],
             "Continent":["Asia","Asia","Europe","Asia","Europe","Africa","Europe","Africa","America","America","America"],
             "Case":[455,93,430,138,5883,2,795,48,213,57,19],
             "Death":["Yes","No","Yes","No","Yes","No","No","No","Yes","No","No"],
             "Death_C":[6,0,5,0,234,0,0,0,11,0,0]}

# %%
df_cov = pd.DataFrame(covid_data)

# %%
df_cov
# Out:
#       Country Continent  Case Death  Death_C
# 0       Japan      Asia   455   Yes        6
# 1    Malaysia      Asia    93    No        0
# 2       Spain    Europe   430   Yes        5
# 3   Singapore      Asia   138    No        0
# 4       Italy    Europe  5883   Yes      234
# 5     Morocco    Africa     2    No        0
# 6     Germany    Europe   795    No        0
# 7       Egypt    Africa    48    No        0
# 8         USA   America   213   Yes       11
# 9      Canada   America    57    No        0
# 10     Brazil   America    19    No        0

# %%
df_cov_g = df_cov.groupby("Continent")

# %%
df_cov_g.groups
# Out:
# {'Africa': [5, 7], 'America': [8, 9, 10], 'Asia': [0, 1, 3], 'Europe': [2, 4, 6]}

# %%
for i, j in df_cov_g:
    print(i)
    print(j)
# Out:
# Africa
#    Country Continent  Case Death  Death_C
# 5  Morocco    Africa     2    No        0
# 7    Egypt    Africa    48    No        0
# America
#    Country Continent  Case Death  Death_C
# 8      USA   America   213   Yes       11
# 9   Canada   America    57    No        0
# 10  Brazil   America    19    No        0
# Asia
#      Country Continent  Case Death  Death_C
# 0      Japan      Asia   455   Yes        6
# 1   Malaysia      Asia    93    No        0
# 3  Singapore      Asia   138    No        0
# Europe
#    Country Continent  Case Death  Death_C
# 2    Spain    Europe   430   Yes        5
# 4    Italy    Europe  5883   Yes      234
# 6  Germany    Europe   795    No        0

# %%
df_cov_g.get_group("Europe")
# Out:
#    Country Continent  Case Death  Death_C
# 2    Spain    Europe   430   Yes        5
# 4    Italy    Europe  5883   Yes      234
# 6  Germany    Europe   795    No        0

# %%
df_cov_g.size()
# Out:
# Continent
# Africa     2
# America    3
# Asia       3
# Europe     3
# dtype: int64

# %%
df_cov_m = df_cov.groupby(["Continent","Death"])

# %%
df_cov_m.size()
# Out:
# Continent  Death
# Africa     No       2
# America    No       2
#            Yes      1
# Asia       No       2
#            Yes      1
# Europe     No       1
#            Yes      2
# dtype: int64

# %%
for i, j in df_cov_m:
    print(i)
    print(j)
# Out:
# ('Africa', 'No')
#    Country Continent  Case Death  Death_C
# 5  Morocco    Africa     2    No        0
# 7    Egypt    Africa    48    No        0
# ('America', 'No')
#    Country Continent  Case Death  Death_C
# 9   Canada   America    57    No        0
# 10  Brazil   America    19    No        0
# ('America', 'Yes')
#   Country Continent  Case Death  Death_C
# 8     USA   America   213   Yes       11
# ('Asia', 'No')
#      Country Continent  Case Death  Death_C
# 1   Malaysia      Asia    93    No        0
# 3  Singapore      Asia   138    No        0
# ('Asia', 'Yes')
#   Country Continent  Case Death  Death_C
# 0   Japan      Asia   455   Yes        6
# ('Europe', 'No')
#    Country Continent  Case Death  Death_C
# 6  Germany    Europe   795    No        0
# ('Europe', 'Yes')
#   Country Continent  Case Death  Death_C
# 2   Spain    Europe   430   Yes        5
# 4   Italy    Europe  5883   Yes      234

# %%
df_cov_m.aggregate(np.sum)
# Out:
#                  Case  Death_C
# Continent Death
# Africa    No       50        0
# America   No       76        0
#           Yes     213       11
# Asia      No      231        0
#           Yes     455        6
# Europe    No      795        0
#           Yes    6313      239

# %%
df_cov_m.agg(np.sum)
# Out:
#                  Case  Death_C
# Continent Death
# Africa    No       50        0
# America   No       76        0
#           Yes     213       11
# Asia      No      231        0
#           Yes     455        6
# Europe    No      795        0
#           Yes    6313      239

# %%
df_cov_g.agg(np.mean).astype(int)
# Out:
#            Case  Death_C
# Continent
# Africa       25        0
# America      96        3
# Asia        228        2
# Europe     2369       79

# %%
df_cov_g["Death_C","Case"].agg([np.sum,np.mean,np.max]).astype(int)
# Out:
# <ipython-input-165-cbd29c75f2f4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_cov_g["Death_C","Case"].agg([np.sum,np.mean,np.max]).astype(int)
#           Death_C            Case
#               sum mean amax   sum  mean  amax
# Continent
# Africa          0    0    0    50    25    48
# America        11    3   11   289    96   213
# Asia            6    2    6   686   228   455
# Europe        239   79  234  7108  2369  5883

# %% [markdown]
# ### Data Munging

# %%
plates = pd.Series({"Car_1":"YE66PUX","Car_2":"LE17SAL","Car_3":"BA64ZET","Car_4":"SA61ZY"})

# %%
plates
# Out:
# Car_1    YE66PUX
# Car_2    LE17SAL
# Car_3    BA64ZET
# Car_4     SA61ZY
# dtype: object

# %%
plates.str.match(r"\w{7}")
# Out:
# Car_1     True
# Car_2     True
# Car_3     True
# Car_4    False
# dtype: bool

# %%
plates = pd.Series({"Car_1":"YE66 PUX","Car_2":"LE17 SAL","Car_3":"BA64 ZET","Car_4":"SA61 ZY"})

# %%
plates.str.contains("[A-Z]{3}")
# Out:
# Car_1     True
# Car_2     True
# Car_3     True
# Car_4    False
# dtype: bool

# %%
plates.str.match("[A-Z]{3}")
# Out:
# Car_1    False
# Car_2    False
# Car_3    False
# Car_4    False
# dtype: bool

# %%
Contacts = [["John Doe","johndoe@abcz.com","1111111111"],
           ["Jane Doe","janedoe@abcz.com","2222222222"],
           ["Charlie Brown","charliebrown@abcz.com","3333333333"]]

# %%
contacts_df = pd.DataFrame(Contacts, columns= ["Name","Email","Phone"])

# %%
contacts_df
# Out:
#             Name                  Email       Phone
# 0       John Doe       johndoe@abcz.com  1111111111
# 1       Jane Doe       janedoe@abcz.com  2222222222
# 2  Charlie Brown  charliebrown@abcz.com  3333333333

# %%
import re

# %%
def get_formatted_phone(value):
    result = re.fullmatch(r"(\d{3})(\d{3})(\d{4})",value)
    return "-".join(result.groups()) if result else value

# %%
f_phone = contacts_df["Phone"].map(get_formatted_phone)

# %%
f_phone
# Out:
# 0    111-111-1111
# 1    222-222-2222
# 2    333-333-3333
# Name: Phone, dtype: object

# %%
contacts_df["Phone"] = f_phone

# %%
contacts_df
# Out:
#             Name                  Email         Phone
# 0       John Doe       johndoe@abcz.com  111-111-1111
# 1       Jane Doe       janedoe@abcz.com  222-222-2222
# 2  Charlie Brown  charliebrown@abcz.com  333-333-3333

# %%
Array1 = np.array([[10,20,np.nan,12],[5,np.nan,np.nan,14],[21,np.nan,10,11],[17,13,10,np.nan]])

# %%
Data_Frame_1 = pd.DataFrame(Array1, index = ["Index1","Index2","Index3","Index4"],
                           columns = ["Column1","Column2","Column3","Column4"])

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.isna()
# Out:
#         Column1  Column2  Column3  Column4
# Index1    False    False     True    False
# Index2    False     True     True    False
# Index3    False     True    False    False
# Index4    False    False    False     True

# %%
Data_Frame_1["Column2"].isna()
# Out:
# Index1    False
# Index2     True
# Index3     True
# Index4    False
# Name: Column2, dtype: bool

# %%
Data_Frame_1.notna()
# Out:
#         Column1  Column2  Column3  Column4
# Index1     True     True    False     True
# Index2     True    False    False     True
# Index3     True    False     True     True
# Index4     True     True     True    False

# %%
Data_Frame_1["Column2"].notna()
# Out:
# Index1     True
# Index2    False
# Index3    False
# Index4     True
# Name: Column2, dtype: bool

# %%
Data_Frame_1.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [Column1, Column2, Column3, Column4]
# Index: []

# %%
Data_Frame_1.dropna(axis=1)
# Out:
#         Column1
# Index1     10.0
# Index2      5.0
# Index3     21.0
# Index4     17.0

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.dropna(thresh=3)
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1["Column2"].sum()
# Out:
# 33.0

# %%
Data_Frame_1["Column2"].mean()
# Out:
# 16.5

# %%
Data_Frame_1.sum()
# Out:
# Column1    53.0
# Column2    33.0
# Column3    20.0
# Column4    37.0
# dtype: float64

# %%
Data_Frame_1.mean()
# Out:
# Column1    13.25
# Column2    16.50
# Column3    10.00
# Column4    12.33
# dtype: float64

# %%
Data_Frame_1.sum().sum()
# Out:
# 143.0

# %%
Data_Frame_1.mean().mean()
# Out:
# 13.020833333333334

# %% [markdown]
# #### Dealing with Missing Data

# %%
array_1 = np.array([[10,20,np.nan,12],[5,np.nan,np.nan,14],[21,np.nan,10,11],[17,13,10,np.nan]])

# %%
Data_Frame_1 = pd.DataFrame(array_1,
                            index = ["Index1","Index2","Index3","Index4"],
                           columns = ["Column1","Column2","Column3","Column4"])

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.fillna(0)
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      0.0     12.0
# Index2      5.0      0.0      0.0     14.0
# Index3     21.0      0.0     10.0     11.0
# Index4     17.0     13.0     10.0      0.0

# %%
Data_Frame_2 = Data_Frame_1.fillna(0)

# %%
Data_Frame_2
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      0.0     12.0
# Index2      5.0      0.0      0.0     14.0
# Index3     21.0      0.0     10.0     11.0
# Index4     17.0     13.0     10.0      0.0

# %%
Data_Frame_1.fillna(method = "bfill")
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0     10.0     12.0
# Index2      5.0     13.0     10.0     14.0
# Index3     21.0     13.0     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.fillna(method = "ffill")
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0     20.0      NaN     14.0
# Index3     21.0     20.0     10.0     11.0
# Index4     17.0     13.0     10.0     11.0

# %%
values = {"Column 1": 22, "Column 2": 33, "Column 3": 44, "Column 4": 55}

# %%
Data_Frame_1.fillna(value=values)
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.fillna(50,limit = 1)
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0     50.0     12.0
# Index2      5.0     50.0      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0     50.0

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.replace(to_replace = np.nan, value = 99)
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0     99.0     12.0
# Index2      5.0     99.0     99.0     14.0
# Index3     21.0     99.0     10.0     11.0
# Index4     17.0     13.0     10.0     99.0

# %%
Data_Frame_1.replace(to_replace = 10.0, value = "Ten")
# Out:
#        Column1  Column2 Column3  Column4
# Index1     Ten     20.0     NaN     12.0
# Index2     5.0      NaN     NaN     14.0
# Index3    21.0      NaN     Ten     11.0
# Index4    17.0     13.0     Ten      NaN

# %%
Data_Frame_3 = pd.DataFrame({"UK":["London","Plymouth","Dublin","Portsmouth"],
                            "USA":["Boston","Pitssburgh","Houston","Fort Worth"],
                            "FR":["Avignon","Le Mans","Dijon","Paris"]})

# %%
Data_Frame_3
# Out:
#            UK         USA       FR
# 0      London      Boston  Avignon
# 1    Plymouth  Pitssburgh  Le Mans
# 2      Dublin     Houston    Dijon
# 3  Portsmouth  Fort Worth    Paris

# %%
Data_Frame_3.replace(to_replace=r"^L", value = "45",regex=True)
# Out:
#            UK         USA        FR
# 0     45ondon      Boston   Avignon
# 1    Plymouth  Pitssburgh  45e Mans
# 2      Dublin     Houston     Dijon
# 3  Portsmouth  Fort Worth     Paris

# %%
Data_Frame_3.replace(to_replace=r"L.*",value="45",regex=True)
# Out:
#            UK         USA       FR
# 0          45      Boston  Avignon
# 1    Plymouth  Pitssburgh       45
# 2      Dublin     Houston    Dijon
# 3  Portsmouth  Fort Worth    Paris

# %%
Data_Frame_1
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0     20.0      NaN     12.0
# Index2      5.0      NaN      NaN     14.0
# Index3     21.0      NaN     10.0     11.0
# Index4     17.0     13.0     10.0      NaN

# %%
Data_Frame_1.interpolate(method="linear", limit_direction="forward")
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0    20.00      NaN     12.0
# Index2      5.0    17.67      NaN     14.0
# Index3     21.0    15.33     10.0     11.0
# Index4     17.0    13.00     10.0     11.0

# %%
Data_Frame_1.interpolate(method="linear", limit_direction='backward')
# Out:
#         Column1  Column2  Column3  Column4
# Index1     10.0    20.00     10.0     12.0
# Index2      5.0    17.67     10.0     14.0
# Index3     21.0    15.33     10.0     11.0
# Index4     17.0    13.00     10.0      NaN

# %% [markdown]
# ### Combining Dataframes

# %%
Sales_1 = {"Chocolate":[70,45,65,35],
          "Bread":[63,51,59,46],
          "Biscuits":[150,90,143,87],
          "Potatoes(kg)":[45,67,38,33],
          "Carrots(kg)":[33,44,45,41],
          "Chips":[35,0,28,70],
          "Crackers":[0,13,45,39]}

# %%
df_month_1 = pd.DataFrame(Sales_1, index= ["Week 1","Week 2","Week 3","Week 4"])

# %%
df_month_1
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# Week 4         35     46        87            33           41     70        39

# %%
Sales_2 = {"Chocolate":[40,35,60,44],
          "Bread":[23,57,39,71],
          "Biscuits":[50,70,45,56],
          "Potatoes(kg)":[25,61,33,41],
          "Carrots(kg)":[53,47,44,39],
          "Chips":[35,13,28,36],
          "Crackers":[27,13,45,47]}

# %%
df_month_2 = pd.DataFrame(Sales_2, index = ["Week 1","Week 2","Week 3","Week 4"])

# %%
df_month_2
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         40     23        50            25           53     35        27
# Week 2         35     57        70            61           47     13        13
# Week 3         60     39        45            33           44     28        45
# Week 4         44     71        56            41           39     36        47

# %%
df_month_3 = pd.DataFrame(Sales_1, index= ["Week 1","Week 2","Week 3","Week 4"])

# %%
df_month_3
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# Week 4         35     46        87            33           41     70        39

# %%
All_Sales = pd.concat([df_month_1,df_month_2,df_month_3])

# %%
All_Sales
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# Week 4         35     46        87            33           41     70        39
# Week 1         40     23        50            25           53     35        27
# Week 2         35     57        70            61           47     13        13
# Week 3         60     39        45            33           44     28        45
# Week 4         44     71        56            41           39     36        47
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# ...

# %%
All_Sales_reindex = pd.concat([df_month_1,df_month_2,df_month_3],ignore_index=True)

# %%
All_Sales_reindex
# Out:
#     Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# 0          70     63       150            45           33     35         0
# 1          45     51        90            67           44      0        13
# 2          65     59       143            38           45     28        45
# 3          35     46        87            33           41     70        39
# 4          40     23        50            25           53     35        27
# 5          35     57        70            61           47     13        13
# 6          60     39        45            33           44     28        45
# 7          44     71        56            41           39     36        47
# 8          70     63       150            45           33     35         0
# 9          45     51        90            67           44      0        13
# 10         65     59       143            38           45     28        45
# ...

# %%
All_Sales_keys = pd.concat([df_month_1,df_month_2,df_month_3],keys=["Month1","Month2","Month3"])

# %%
All_Sales_keys
# Out:
#                Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  \
# Month1 Week 1         70     63       150            45           33     35
#        Week 2         45     51        90            67           44      0
#        Week 3         65     59       143            38           45     28
#        Week 4         35     46        87            33           41     70
# Month2 Week 1         40     23        50            25           53     35
#        Week 2         35     57        70            61           47     13
#        Week 3         60     39        45            33           44     28
#        Week 4         44     71        56            41           39     36
# Month3 Week 1         70     63       150            45           33     35
#        Week 2         45     51        90            67           44      0
#        Week 3         65     59       143            38           45     28
# ...

# %%
All_Sales_keys.loc["Month2"]
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         40     23        50            25           53     35        27
# Week 2         35     57        70            61           47     13        13
# Week 3         60     39        45            33           44     28        45
# Week 4         44     71        56            41           39     36        47

# %%
All_Sales_keys = pd.concat([df_month_1,df_month_2,df_month_3], keys=["Month 1","Month 2","Month 3"], axis = 0)

# %%
All_Sales_keys
# Out:
#                 Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  \
# Month 1 Week 1         70     63       150            45           33     35
#         Week 2         45     51        90            67           44      0
#         Week 3         65     59       143            38           45     28
#         Week 4         35     46        87            33           41     70
# Month 2 Week 1         40     23        50            25           53     35
#         Week 2         35     57        70            61           47     13
#         Week 3         60     39        45            33           44     28
#         Week 4         44     71        56            41           39     36
# Month 3 Week 1         70     63       150            45           33     35
#         Week 2         45     51        90            67           44      0
#         Week 3         65     59       143            38           45     28
# ...

# %%
All_Sales_keys = pd.concat([df_month_1,df_month_2,df_month_3],keys = ["Month 1","Month 2","Month 3"], axis = 1)

# %%
All_Sales_keys
# Out:
#          Month 1                                                         \
#        Chocolate Bread Biscuits Potatoes(kg) Carrots(kg) Chips Crackers
# Week 1        70    63      150           45          33    35        0
# Week 2        45    51       90           67          44     0       13
# Week 3        65    59      143           38          45    28       45
# Week 4        35    46       87           33          41    70       39
#
#          Month 2                 ...                              Month 3  \
#        Chocolate Bread Biscuits  ... Carrots(kg) Chips Crackers Chocolate
# Week 1        40    23       50  ...          53    35       27        70
# Week 2        35    57       70  ...          47    13       13        45
# Week 3        60    39       45  ...          44    28       45        65
# Week 4        44    71       56  ...          39    36       47        35
#
#
#        Bread Biscuits Potatoes(kg) Carrots(kg) Chips Crackers
# ...

# %%
df_month_2 = pd.DataFrame(Sales_2, index = ["Week 4","Week 5","Week 6","Week 7"])

# %%
All_Sales_keys = pd.concat([df_month_1,df_month_2,df_month_3],keys = ["Month 1","Month 2","Month 3"], axis = 0)

# %%
All_Sales_keys
# Out:
#                 Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  \
# Month 1 Week 1         70     63       150            45           33     35
#         Week 2         45     51        90            67           44      0
#         Week 3         65     59       143            38           45     28
#         Week 4         35     46        87            33           41     70
# Month 2 Week 4         40     23        50            25           53     35
#         Week 5         35     57        70            61           47     13
#         Week 6         60     39        45            33           44     28
#         Week 7         44     71        56            41           39     36
# Month 3 Week 1         70     63       150            45           33     35
#         Week 2         45     51        90            67           44      0
#         Week 3         65     59       143            38           45     28
# ...

# %%
All_Sales_keys = pd.concat([df_month_1,df_month_2,df_month_3],keys = ["Month 1","Month 2","Month 3"], axis = 1)

# %%
All_Sales_keys
# Out:
#          Month 1                                                         \
#        Chocolate Bread Biscuits Potatoes(kg) Carrots(kg) Chips Crackers
# Week 1      70.0  63.0    150.0         45.0        33.0  35.0      0.0
# Week 2      45.0  51.0     90.0         67.0        44.0   0.0     13.0
# Week 3      65.0  59.0    143.0         38.0        45.0  28.0     45.0
# Week 4      35.0  46.0     87.0         33.0        41.0  70.0     39.0
# Week 5       NaN   NaN      NaN          NaN         NaN   NaN      NaN
# Week 6       NaN   NaN      NaN          NaN         NaN   NaN      NaN
# Week 7       NaN   NaN      NaN          NaN         NaN   NaN      NaN
#
#          Month 2                 ...                              Month 3  \
#        Chocolate Bread Biscuits  ... Carrots(kg) Chips Crackers Chocolate
# Week 1       NaN   NaN      NaN  ...         NaN   NaN      NaN      70.0
# Week 2       NaN   NaN      NaN  ...         NaN   NaN      NaN      45.0
# ...

# %%
wadf = df_month_1.append([df_month_2,df_month_3])

# %%
wadf
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# Week 4         35     46        87            33           41     70        39
# Week 4         40     23        50            25           53     35        27
# Week 5         35     57        70            61           47     13        13
# Week 6         60     39        45            33           44     28        45
# Week 7         44     71        56            41           39     36        47
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# ...

# %%
wadf = df_month_1.append([df_month_2,df_month_3], ignore_index=True)

# %%
wadf
# Out:
#     Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# 0          70     63       150            45           33     35         0
# 1          45     51        90            67           44      0        13
# 2          65     59       143            38           45     28        45
# 3          35     46        87            33           41     70        39
# 4          40     23        50            25           53     35        27
# 5          35     57        70            61           47     13        13
# 6          60     39        45            33           44     28        45
# 7          44     71        56            41           39     36        47
# 8          70     63       150            45           33     35         0
# 9          45     51        90            67           44      0        13
# 10         65     59       143            38           45     28        45
# ...

# %%
#Merge
Sales_1 = {"Chocolate":[70,45,65,35],
          "Bread":[63,51,59,46],
          "Biscuits":[150,90,143,87],
          "Potatoes(kg)":[45,67,38,33],
          "Carrots(kg)":[33,44,45,41],
          "Chips":[35,0,28,70],
          "Crackers":[0,13,45,39]}

# %%
df_month_1 = pd.DataFrame(Sales_1,index = ["Week 1","Week 2","Week 3","Week 4"])

# %%
df_month_1
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         70     63       150            45           33     35         0
# Week 2         45     51        90            67           44      0        13
# Week 3         65     59       143            38           45     28        45
# Week 4         35     46        87            33           41     70        39

# %%
Sales_2 = {"Chocolate":[40,35,60,44],
          "Bread":[23,57,39,71],
          "Biscuits":[50,70,45,56],
          "Potatoes(kg)":[25,61,33,41],
          "Carrots(kg)":[53,47,44,39],
          "Chips":[35,13,28,36],
          "Crackers":[27,13,45,47]}

# %%
df_month_2 = pd.DataFrame(Sales_2,index= ["Week 1","Week 2","Week 3","Week 4"])

# %%
df_month_2
# Out:
#         Chocolate  Bread  Biscuits  Potatoes(kg)  Carrots(kg)  Chips  Crackers
# Week 1         40     23        50            25           53     35        27
# Week 2         35     57        70            61           47     13        13
# Week 3         60     39        45            33           44     28        45
# Week 4         44     71        56            41           39     36        47

# %%
m_data_1 = pd.merge(df_month_1,df_month_2, on = "Chips")

# %%
m_data_1
# Out:
#    Chocolate_x  Bread_x  Biscuits_x  Potatoes(kg)_x  Carrots(kg)_x  Chips  \
# 0           70       63         150              45             33     35
# 1           65       59         143              38             45     28
#
#    Crackers_x  Chocolate_y  Bread_y  Biscuits_y  Potatoes(kg)_y  \
# 0           0           40       23          50              25
# 1          45           60       39          45              33
#
#    Carrots(kg)_y  Crackers_y
# 0             53          27
# 1             44          45

# %%
m_data_2 = pd.merge(df_month_1,df_month_2, how = "outer",on='Chips')

# %%
m_data_2
# Out:
#    Chocolate_x  Bread_x  Biscuits_x  Potatoes(kg)_x  Carrots(kg)_x  Chips  \
# 0         70.0     63.0       150.0            45.0           33.0     35
# 1         45.0     51.0        90.0            67.0           44.0      0
# 2         65.0     59.0       143.0            38.0           45.0     28
# 3         35.0     46.0        87.0            33.0           41.0     70
# 4          NaN      NaN         NaN             NaN            NaN     13
# 5          NaN      NaN         NaN             NaN            NaN     36
#
#    Crackers_x  Chocolate_y  Bread_y  Biscuits_y  Potatoes(kg)_y  \
# 0         0.0         40.0     23.0        50.0            25.0
# 1        13.0          NaN      NaN         NaN             NaN
# 2        45.0         60.0     39.0        45.0            33.0
# 3        39.0          NaN      NaN         NaN             NaN
# 4         NaN         35.0     57.0        70.0            61.0
# ...

# %%
m_data_3 = pd.merge(df_month_1,df_month_2, how = "left", on = "Chips")

# %%
m_data_3
# Out:
#    Chocolate_x  Bread_x  Biscuits_x  Potatoes(kg)_x  Carrots(kg)_x  Chips  \
# 0           70       63         150              45             33     35
# 1           45       51          90              67             44      0
# 2           65       59         143              38             45     28
# 3           35       46          87              33             41     70
#
#    Crackers_x  Chocolate_y  Bread_y  Biscuits_y  Potatoes(kg)_y  \
# 0           0         40.0     23.0        50.0            25.0
# 1          13          NaN      NaN         NaN             NaN
# 2          45         60.0     39.0        45.0            33.0
# 3          39          NaN      NaN         NaN             NaN
#
#    Carrots(kg)_y  Crackers_y
# 0           53.0        27.0
# 1            NaN         NaN
# 2           44.0        45.0
# 3            NaN         NaN

# %%
join_right = pd.DataFrame({"Apple":["Apfel","Mela","Manzana","Pomme"],
                          "Orange":["Orange","Arancia","Naranja","Orange"],
                          "Banana":["Banane","Banana","Platano","Banane"]},
                         index = ["German","Italian","Spanish","French"])

# %%
join_right
# Out:
#            Apple   Orange   Banana
# German     Apfel   Orange   Banane
# Italian     Mela  Arancia   Banana
# Spanish  Manzana  Naranja  Platano
# French     Pomme   Orange   Banane

# %%
join_left = pd.DataFrame({"One":["Ein","Uno","Una","Un","Unus"],
                         "Two":["Zwei","Duo","Dos","Deux","Duo"],
                         "Three":["Drei","Tre","Tres","Trois","Tribus"]},
                        index = ["German","Italian","Spanish","French","Latin"])

# %%
join_left
# Out:
#           One   Two   Three
# German    Ein  Zwei    Drei
# Italian   Uno   Duo     Tre
# Spanish   Una   Dos    Tres
# French     Un  Deux   Trois
# Latin    Unus   Duo  Tribus

# %%
result_1 = join_right.join(join_left)

# %%
result_1
# Out:
#            Apple   Orange   Banana  One   Two  Three
# German     Apfel   Orange   Banane  Ein  Zwei   Drei
# Italian     Mela  Arancia   Banana  Uno   Duo    Tre
# Spanish  Manzana  Naranja  Platano  Una   Dos   Tres
# French     Pomme   Orange   Banane   Un  Deux  Trois

# %%
result_2 = join_left.join(join_right)

# %%
result_2
# Out:
#           One   Two   Three    Apple   Orange   Banana
# German    Ein  Zwei    Drei    Apfel   Orange   Banane
# Italian   Uno   Duo     Tre     Mela  Arancia   Banana
# Spanish   Una   Dos    Tres  Manzana  Naranja  Platano
# French     Un  Deux   Trois    Pomme   Orange   Banane
# Latin    Unus   Duo  Tribus      NaN      NaN      NaN

# %%
join_right = pd.DataFrame({"Apple":["Apfel","Mela","Manzana","Pomme"],
                          "Orange":["Orange","Arancia","Naranja","Orange"],
                          "Banana":["Banane","Banana","Platano","Banane"],
                         "key":["German","Italian","Spanish","French"]})

# %%
result_3 = join_right.join(join_left, on = "key")

# %%
result_3
# Out:
#      Apple   Orange   Banana      key  One   Two  Three
# 0    Apfel   Orange   Banane   German  Ein  Zwei   Drei
# 1     Mela  Arancia   Banana  Italian  Uno   Duo    Tre
# 2  Manzana  Naranja  Platano  Spanish  Una   Dos   Tres
# 3    Pomme   Orange   Banane   French   Un  Deux  Trois

# %% [markdown]
# ### Importing Files

# %%
Sales = pd.read_csv("Sales.csv")

# %%
Sales.head(4)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
#
#   Sales Channel  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0       Offline   5/28/2010  669165933   6/27/2010        9925      255.28
# 1        Online   8/22/2012  963881480   9/15/2012        2804      205.70
# 2       Offline  05/02/2014  341417157  05/08/2014        1779      651.21
# 3        Online   6/20/2014  514321792  07/05/2014        8102        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42     2533654.00  1582243.50     951410.50
# 1     117.11      576782.80   328376.44     248406.36
# ...

# %%
Sales.drop(["Sales Channel","Order ID"],axis= 1)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
del Sales["Order ID"]

# %%
Sales
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
Sales.sort_values("Total Profit")
# Out:
#                                Region                Country        Item Type  \
# 23              Australia and Oceania            New Zealand           Fruits
# 10                               Asia             Kyrgyzstan       Vegetables
# 36       Middle East and North Africa                  Syria           Fruits
# 26              Australia and Oceania               Kiribati           Fruits
# 27                 Sub-Saharan Africa                   Mali           Fruits
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 31                 Sub-Saharan Africa            South Sudan    Personal Care
# 28                             Europe                 Norway        Beverages
# 17                 Sub-Saharan Africa               Cameroon        Beverages
# 21                             Europe               Portugal        Baby Food
# 22  Central America and the Caribbean               Honduras           Snacks
# ...

# %%
Sales.sort_values("Total Profit", ascending = False).head()
# Out:
#                                Region      Country  Item Type Sales Channel  \
# 30                             Europe  Switzerland  Cosmetics       Offline
# 13  Central America and the Caribbean     Honduras  Household       Offline
# 33                               Asia      Myanmar  Household       Offline
# 16                               Asia    Sri Lanka  Cosmetics       Offline
# 0               Australia and Oceania       Tuvalu  Baby Food       Offline
#
#     Order Date   Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 30   9/17/2012  10/20/2012        8661      437.20     263.33     3786589.20
# 13  02/08/2017   2/13/2017        8974      668.27     502.54     5997054.98
# 33   1/16/2015  03/01/2015        8250      668.27     502.54     5513227.50
# 16  11/19/2016  12/18/2016        6952      437.20     263.33     3039414.40
# 0    5/28/2010   6/27/2010        9925      255.28     159.42     2533654.00
#
#     Total Cost  Total Profit
# ...

# %%
Sales.sort_values("Units Sold", ascending = False).tail()
# Out:
#     Region     Country        Item Type Sales Channel  Order Date   Ship Date  \
# 25  Europe      France        Cosmetics        Online   5/22/2017  06/05/2017
# 2   Europe      Russia  Office Supplies       Offline  05/02/2014  05/08/2014
# 15  Europe    Bulgaria          Clothes        Online   4/23/2012  06/03/2012
# 21  Europe    Portugal        Baby Food        Online   7/31/2015  09/03/2015
# 10    Asia  Kyrgyzstan       Vegetables        Online   6/24/2011  07/12/2011
#
#     Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 25        1815      437.20     263.33      793518.00   477943.95     315574.05
# 2         1779      651.21     524.96     1158502.59   933903.84     224598.75
# 15        1673      109.28      35.84      182825.44    59960.32     122865.12
# 21        1273      255.28     159.42      324971.44   202941.66     122029.78
# 10         124      154.06      90.93       19103.44    11275.32       7828.12

# %%
Sales["Item Type"].value_counts()
# Out:
# Fruits             5
# Personal Care      5
# Household          5
# Baby Food          4
# Office Supplies    4
# Cosmetics          3
# Clothes            3
# Beverages          2
# Vegetables         2
# Snacks             2
# Meat               2
# Cereal             2
# Name: Item Type, dtype: int64

# %%
Sales_C = Sales

# %%
Sales_C.to_csv("Sales_C.csv")
